# %%
from pprint import pprint
import pandas as pd

# %%
from tf.app import use

A = use("etcbc/bhsa", hoist=globals())
Fmt = F
Lmt = L
Tmt = T

B = use("etcbc/dss", checkout="clone", version="1.8", hoist=globals())
Fdss = F
Ldss = L
Tdss = T

# here we rename the functions F L and T so the DSS functions does not overwrite the BHSA functions
# checkout="clone" is to look for the data set in the folder ~/github
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8=#eb1eef532de43783a548afed016937f55572bac6 offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.8=#eb1eef532de43783a548afed016937f55572bac6 offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#aba4367b49750089e4e4122415a77cac43bd97bc offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#f45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.2.3</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">etcbc - bhsa 2021</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="etcbc - bhsa feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     <tr>
#
# <tr>
#     <th>book</th>
#     <td>39</td>
#     <td>10938.21</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>929</td>
#     <td>459.19</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>9230</td>
#     <td>46.22</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>23213</td>
#     <td>18.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>half_verse</th>
#     <td>45179</td>
#     <td>9.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>63717</td>
#     <td>6.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence_atom</th>
#     <td>64514</td>
#     <td>6.61</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>88131</td>
#     <td>4.84</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause_atom</th>
#     <td>90704</td>
#     <td>4.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>253203</td>
#     <td>1.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase_atom</th>
#     <td>267532</td>
#     <td>1.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>113850</td>
#     <td>1.42</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>426590</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedness of phrase(atom) (det; und; NA.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ text type of clause (? (Unknown); N (narrative); D (discursive); Q (Quotation).)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/freq_lex.tf">freq_lex</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ frequency of lexemes</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ syntactic function of phrase (Cmpl; Objc; Pred; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-transliterated (B R>CJT BR> >LHJM ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_cons_utf8.tf">g_cons_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word consonantal-Hebrew (ב ראשׁית ברא אלהים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex.tf">g_lex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-transliterated (B.:- R;>CIJT B.@R@> >:ELOH ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_lex_utf8.tf">g_lex_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ lexeme pointed-Hebrew (בְּ רֵאשִׁית בָּרָא אֱלֹה)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word.tf">g_word</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-transliterated (B.:- R;>CI73JT B.@R@74> >:ELOHI92JM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/g_word_utf8.tf">g_word_utf8</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ word pointed-Hebrew (בְּ רֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> 🆗 english translation of lexeme (beginning create god(s))</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/gn.tf">gn</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ grammatical gender (m; f; NA; unknown.)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="htt
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8.1=#34aba7b1869bfb35234d922c71f37167be783de9 offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under C:/Users/zht702/github">~/github/etcbc/dss/tf/1.8</span>
# <b title="local github">data:</b> <span title="repo clone offline under C:/Users/zht702/github">~/github/etcbc/dss/parallels/tf/1.8</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.2.3</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/app" title="etcbc/dss app">etcbc/dss/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/about.md" title="provenance of Dead Sea Scrolls">etcbc - dss 1.8</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="etcbc - dss feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     <tr>
#
# <tr>
#     <th>scroll</th>
#     <td>1001</td>
#     <td>1428.81</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>10450</td>
#     <td>129.14</td>
#     <td>94</td>
# </tr>
#
# <tr>
#     <th>fragment</th>
#     <td>11182</td>
#     <td>127.91</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>line</th>
#     <td>52895</td>
#     <td>27.04</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>125</td>
#     <td>12.85</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>cluster</th>
#     <td>101099</td>
#     <td>6.68</td>
#     <td>47</td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>315</td>
#     <td>5.10</td>
#     <td>0</td>
# </tr>
#
# <tr>
#     <th>word</th>
#     <td>500995</td>
#     <td>2.81</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>sign</i></th>
#     <td>1430241</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/dss/blob/master/programs/parallels.ipynb" title="~/github/etcbc/dss/parallels/tf/1.8/sim.tf">sim</a>
# </div>
# <div class="fmono">int</div>
#
# <span> similarity between lines, as a percentage of the common material wrt the combined material</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>Dead Sea Scrolls</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> space behind the word, if any</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/alt.tf">alt</a>
# </div>
# <div class="fmono">int</div>
#
# <span> alternative reading</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/biblical.tf">biblical</a>
# </div>
# <div class="fmono">int</div>
#
# <span> whether we are in biblical material or not</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> acronym of the book in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/book_etcbc.tf">book_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/chapter.tf">chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of the chapter in which the word occurs</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/cl.tf">cl</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/cl2.tf">cl2</a>
# </div>
# <div class="fmono">str</div>
#
# <span> class (for part 2) (morphology tag)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/cor.tf">cor</a>
# </div>
# <div class="fmono">int</div>
#
# <span> correction made by an ancient or modern editor</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/fragment.tf">fragment</a>
# </div>
# <div class="fmono">str</div>
#
# <span> label of a fragment of a scroll</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/full.tf">full</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (Unicode) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/fulle.tf">fulle</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (ETCBC transliteration) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/fullo.tf">fullo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> full transcription (original source) of a word including flags and brackets</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/g_cons.tf">g_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/g_prs_etcbc.tf">g_prs_etcbc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Dead Sea Scrolls: additions based on BHSA and machine learning</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/glex.tf">glex</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (Unicode) of a lexeme leaving out non-letters</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/glexe.tf">glexe</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (ETCBC transliteration) of a lexeme leaving out non-letters</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/transcription.md" title="~/github/etcbc/dss/tf/1.8/glexo.tf">glexo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> representation (original source) of a lexeme leaving out non-le
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %% [markdown]
# What we are going to do now: for each occurrence of halak, we want to collect tf ID, book, chapter, verse, scroll name, stem, consonant rep. of the word, person number gender
#
# otype: specifies the object type that we are looking for

# %%
halak_info = {}

book_names = set()

for word in Fmt.otype.s("word"):
    if Fmt.lex.v(word) == "HLK[":
        book, chapter, verse = Tmt.sectionFromNode(word)
        book_names.add(book)
        stem = Fmt.vs.v(word)
        verbal_tense = Fmt.vt.v(word)
        consonant_rep = Fmt.g_cons.v(word)
        language = Fmt.language.v(word)
        features = [word, book, str(chapter), str(verse), "MT", stem, verbal_tense, consonant_rep, language]
        halak_info[word] = features

# %% [markdown]
# Structure in the DSS dataset: instead of book chpter verse being object typem they are features of word
# book is a feature: word level feature, give the biblical book where the word occurs

# %%
for word in Fdss.otype.s("word"):
    if Fdss.lex_etcbc.v(word) == "HLK[":
        book = Fdss.book_etcbc.v(word)
        chapter = Fdss.chapter.v(word)
        verse = Fdss.verse.v(word)
        scroll = Ldss.u(word, "scroll")[0]
        scroll_name = Tdss.scrollName(scroll)
        stem = Fdss.vs_etcbc.v(word)
        verbal_tense = Fdss.vt_etcbc.v(word)
        consonant_rep = Fdss.g_cons.v(word)
        language = Fdss.lang_etcbc.v(word)
        if book and book in book_names:   
            features = [word, book, chapter, verse, scroll_name, stem, verbal_tense, consonant_rep, language]
            halak_info[word] = features

# %%
pprint(halak_info)
# Out:
# {935: [935, 'Genesis', '2', '14', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  1321: [1321, 'Genesis', '3', '8', 'MT', 'hit', 'ptca', 'MTHLK', 'Hebrew'],
#  1449: [1449, 'Genesis', '3', '14', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  2424: [2424, 'Genesis', '5', '22', 'MT', 'hit', 'wayq', 'JTHLK', 'Hebrew'],
#  2455: [2455, 'Genesis', '5', '24', 'MT', 'hit', 'wayq', 'JTHLK', 'Hebrew'],
#  2781: [2781, 'Genesis', '6', '9', 'MT', 'hit', 'perf', 'HTHLK', 'Hebrew'],
#  3407: [3407, 'Genesis', '7', '18', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  3598: [3598, 'Genesis', '8', '3', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  3634: [3634, 'Genesis', '8', '5', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  4451: [4451, 'Genesis', '9', '23', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  5460: [5460, 'Genesis', '11', '31', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  5489: [5489, 'Genesis', '12', '1', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  5532: [5532, 'Genesis', '12', '4', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  5540: [5540, 'Genesis', '12', '4', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  5583: [5583, 'Genesis', '12', '5', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  5668: [5668, 'Genesis', '12', '9', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  5849: [5849, 'Genesis', '12', '19', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  5898: [5898, 'Genesis', '13', '3', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  5944: [5944, 'Genesis', '13', '5', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  6181: [6181, 'Genesis', '13', '17', 'MT', 'hit', 'impv', 'HTHLK', 'Hebrew'],
#  6423: [6423, 'Genesis', '14', '11', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  6435: [6435, 'Genesis', '14', '12', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  6661: [6661, 'Genesis', '14', '24', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  6704: [6704, 'Genesis', '15', '2', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  7189: [7189, 'Genesis', '16', '8', 'MT', 'qal', 'impf', 'TLKJ', 'Hebrew'],
#  7344: [7344, 'Genesis', '17', '1', 'MT', 'hit', 'impv', 'HTHLK', 'Hebrew'],
#  8088: [8088, 'Genesis', '18', '16', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  8185: [8185, 'Genesis', '18', '22', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  8410: [8410, 'Genesis', '18', '33', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  8468: [8468, 'Genesis', '19', '2', 'MT', 'qal', 'perf', 'HLKTM', 'Hebrew'],
#  9112: [9112, 'Genesis', '19', '32', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  9851: [9851, 'Genesis', '21', '14', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  9875: [9875, 'Genesis', '21', '16', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  9963: [9963, 'Genesis', '21', '19', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  10254: [10254, 'Genesis', '22', '2', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  10299: [10299, 'Genesis', '22', '3', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  10341: [10341, 'Genesis', '22', '5', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  10373: [10373, 'Genesis', '22', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  10415: [10415, 'Genesis', '22', '8', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  10531: [10531, 'Genesis', '22', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  10642: [10642, 'Genesis', '22', '19', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  11173: [11173, 'Genesis', '24', '4', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  11192: [11192, 'Genesis', '24', '5', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  11272: [11272, 'Genesis', '24', '8', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  11313: [11313, 'Genesis', '24', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  11323: [11323, 'Genesis', '24', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  11851: [11851, 'Genesis', '24', '38', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  11866: [11866, 'Genesis', '24', '39', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  11875: [11875,
#          'Genesis',
#          '24',
#          '40',
#          'MT',
#          'hit',
#          'perf',
#          'HTHLKTJ',
#          'Hebrew'],
#  11933: [11933, 'Genesis', '24', '42', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  12130: [12130, 'Genesis', '24', '51', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  12213: [12213, 'Genesis', '24', '55', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  12226: [12226, 'Genesis', '24', '56', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  12247: [12247, 'Genesis', '24', '58', 'MT', 'qal', 'impf', 'TLKJ', 'Hebrew'],
#  12255: [12255, 'Genesis', '24', '58', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  12301: [12301, 'Genesis', '24', '61', 'MT', 'qal', 'wayq', 'TLKNH', 'Hebrew'],
#  12312: [12312, 'Genesis', '24', '61', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  12373: [12373, 'Genesis', '24', '65', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  12774: [12774, 'Genesis', '25', '22', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  12930: [12930, 'Genesis', '25', '32', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  12971: [12971, 'Genesis', '25', '34', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  12997: [12997, 'Genesis', '26', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  13239: [13239, 'Genesis', '26', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  13240: [13240, 'Genesis', '26', '13', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  13284: [13284, 'Genesis', '26', '16', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  13292: [13292, 'Genesis', '26', '17', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  13467: [13467, 'Genesis', '26', '26', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  13559: [13559, 'Genesis', '26', '31', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  13715: [13715, 'Genesis', '27', '5', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  13770: [13770, 'Genesis', '27', '9', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  13849: [13849, 'Genesis', '27', '13', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  13853: [13853, 'Genesis', '27', '14', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  14520: [14520, 'Genesis', '28', '2', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  14579: [14579, 'Genesis', '28', '5', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  14636: [14636, 'Genesis', '28', '7', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  14651: [14651, 'Genesis', '28', '9', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  14677: [14677, 'Genesis', '28', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  14788: [14788, 'Genesis', '28', '15', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  14907: [14907, 'Genesis', '28', '20', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  14955: [14955, 'Genesis', '29', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  15082: [15082, 'Genesis', '29', '7', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  15777: [15777, 'Genesis', '30', '14', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  15983: [15983, 'Genesis', '30', '25', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  16000: [16000, 'Genesis', '30', '26', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  16715: [16715, 'Genesis', '31', '19', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  16923: [16923, 'Genesis', '31', '30', 'MT', 'qal', 'infa', 'HLK', 'Hebrew'],
#  16924: [16924, 'Genesis', '31', '30', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  17235: [17235, 'Genesis', '31', '44', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  17449: [17449, 'Genesis', '32', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  17457: [17457, 'Genesis', '32', '2', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  17554: [17554, 'Genesis', '32', '7', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  17788: [17788, 'Genesis', '32', '18', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  17827: [17827, 'Genesis', '32', '20', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  17859: [17859, 'Genesis', '32', '21', 'MT', 'qal', 'ptca', 'HLKT', 'Hebrew'],
#  18291: [18291, 'Genesis', '33', '12', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  18293: [18293, 'Genesis', '33', '12', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  18750: [18750, 'Genesis', '34', '17', 'MT', 'qal', 'perf', 'HLKNW', 'Hebrew'],
#  19121: [19121, 'Genesis', '35', '3', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  19445: [19445, 'Genesis', '35', '22', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  19652: [19652, 'Genesis', '36', '6', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  20390: [20390, 'Genesis', '37', '12', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  20410: [20410, 'Genesis', '37', '13', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  20421: [20421, 'Genesis', '37', '14', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  20482: [20482, 'Genesis', '37', '17', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  20485: [20485, 'Genesis', '37', '17', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  20522: [20522, 'Genesis', '37', '20', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  20644: [20644, 'Genesis', '37', '25', 'MT', 'qal', 'ptca', 'HWLKJM', 'Hebrew'],
#  20663: [20663, 'Genesis', '37', '27', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  21019: [21019, 'Genesis', '38', '11', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  21179: [21179, 'Genesis', '38', '19', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  23380: [23380, 'Genesis', '41', '55', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  23740: [23740, 'Genesis', '42', '19', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  23882: [23882, 'Genesis', '42', '26', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  24020: [24020, 'Genesis', '42', '33', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  24131: [24131, 'Genesis', '42', '38', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  24282: [24282, 'Genesis', '43', '8', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  25779: [25779, 'Genesis', '45', '17', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  25911: [25911, 'Genesis', '45', '24', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  25988: [25988, 'Genesis', '45', '28', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  27589: [27589, 'Genesis', '48', '15', 'MT', 'hit', 'perf', 'HTHLKW', 'Hebrew'],
#  28604: [28604, 'Genesis', '50', '18', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  29115: [29115, 'Exodus', '2', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  29197: [29197, 'Exodus', '2', '5', 'MT', 'qal', 'ptca', 'HLKT', 'Hebrew'],
#  29245: [29245, 'Exodus', '2', '7', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  29265: [29265, 'Exodus', '2', '8', 'MT', 'qal', 'impv', 'LKJ', 'Hebrew'],
#  29267: [29267, 'Exodus', '2', '8', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  29281: [29281, 'Exodus', '2', '9', 'MT', 'hif', 'impv', 'HJLJKJ', 'Hebrew'],
#  29848: [29848, 'Exodus', '3', '10', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  29870: [29870, 'Exodus', '3', '11', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  29988: [29988, 'Exodus', '3', '16', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  30075: [30075, 'Exodus', '3', '18', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  30098: [30098, 'Exodus', '3', '19', 'MT', 'qal', 'infc', 'HLK', 'Hebrew'],
#  30138: [30138, 'Exodus', '3', '21', 'MT', 'qal', 'impf', 'TLKWN', 'Hebrew'],
#  30140: [30140, 'Exodus', '3', '21', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  30421: [30421, 'Exodus', '4', '12', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  30532: [30532, 'Exodus', '4', '18', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  30542: [30542, 'Exodus', '4', '18', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  30561: [30561, 'Exodus', '4', '18', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  30571: [30571, 'Exodus', '4', '19', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  30615: [30615, 'Exodus', '4', '21', 'MT', 'qal', 'infc', 'LKTK', 'Hebrew'],
#  30720: [30720, 'Exodus', '4', '27', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  30727: [30727, 'Exodus', '4', '27', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  30756: [30756, 'Exodus', '4', '29', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  30862: [30862, 'Exodus', '5', '3', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  30899: [30899, 'Exodus', '5', '4', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  30951: [30951, 'Exodus', '5', '7', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  30980: [30980, 'Exodus', '5', '8', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  31021: [31021, 'Exodus', '5', '11', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  31134: [31134, 'Exodus', '5', '17', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  31140: [31140, 'Exodus', '5', '18', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  32030: [32030, 'Exodus', '7', '15', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  32866: [32866, 'Exodus', '8', '21', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  32901: [32901, 'Exodus', '8', '23', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  32933: [32933, 'Exodus', '8', '24', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  33526: [33526, 'Exodus', '9', '23', 'MT', 'qal', 'wayq', 'THLK', 'Hebrew'],
#  33987: [33987, 'Exodus', '10', '8', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  33996: [33996, 'Exodus', '10', '8', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  34005: [34005, 'Exodus', '10', '9', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  34016: [34016, 'Exodus', '10', '9', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  34042: [34042, 'Exodus', '10', '11', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  34353: [34353, 'Exodus', '10', '24', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  34364: [34364, 'Exodus', '10', '24', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  34385: [34385, 'Exodus', '10', '26', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  34424: [34424, 'Exodus', '10', '28', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  35324: [35324, 'Exodus', '12', '28', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  35418: [35418, 'Exodus', '12', '31', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  35433: [35433, 'Exodus', '12', '32', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  36193: [36193, 'Exodus', '13', '21', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  36213: [36213, 'Exodus', '13', '21', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  36599: [36599, 'Exodus', '14', '19', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  36605: [36605, 'Exodus', '14', '19', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  36658: [36658, 'Exodus', '14', '21', 'MT', 'hif', 'wayq', 'JWLK', 'Hebrew'],
#  36847: [36847, 'Exodus', '14', '29', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  37166: [37166, 'Exodus', '15', '19', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  37228: [37228, 'Exodus', '15', '22', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  37464: [37464, 'Exodus', '16', '4', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  38252: [38252, 'Exodus', '17', '5', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  38893: [38893, 'Exodus', '18', '20', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  39050: [39050, 'Exodus', '18', '27', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  39261: [39261, 'Exodus', '19', '10', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  39467: [39467, 'Exodus', '19', '19', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  39564: [39564, 'Exodus', '19', '24', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  40277: [40277, 'Exodus', '21', '19', 'MT', 'hit', 'perf', 'HTHLK', 'Hebrew'],
#  41403: [41403, 'Exodus', '23', '23', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  46531: [46531, 'Exodus', '32', '1', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  46651: [46651, 'Exodus', '32', '7', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  47007: [47007, 'Exodus', '32', '23', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  47232: [47232, 'Exodus', '32', '34', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  47243: [47243, 'Exodus', '32', '34', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  47274: [47274, 'Exodus', '33', '1', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  47609: [47609, 'Exodus', '33', '14', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  47619: [47619, 'Exodus', '33', '15', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  47640: [47640, 'Exodus', '33', '16', 'MT', 'qal', 'infc', 'LKTK', 'Hebrew'],
#  47957: [47957, 'Exodus', '34', '9', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  58165: [58165, 'Leviticus', '11', '20', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  58181: [58181, 'Leviticus', '11', '21', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  58288: [58288, 'Leviticus', '11', '27', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  58296: [58296, 'Leviticus', '11', '27', 'MT', 'qal', 'ptca', 'HLKT', 'Hebrew'],
#  58570: [58570, 'Leviticus', '11', '42', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  58575: [58575, 'Leviticus', '11', '42', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  63435: [63435, 'Leviticus', '18', '3', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  63444: [63444, 'Leviticus', '18', '4', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  64045: [64045, 'Leviticus', '19', '16', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  64843: [64843, 'Leviticus', '20', '23', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  68184: [68184, 'Leviticus', '26', '3', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  68318: [68318,
#          'Leviticus',
#          '26',
#          '12',
#          'MT',
#          'hit',
#          'perf',
#          'HTHLKTJ',
#          'Hebrew'],
#  68350: [68350, 'Leviticus', '26', '13', 'MT', 'hif', 'wayq', '>WLK', 'Hebrew'],
#  68491: [68491, 'Leviticus', '26', '21', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  68535: [68535,
#          'Leviticus',
#          '26',
#          '23',
#          'MT',
#          'qal',
#          'perf',
#          'HLKTM',
#          'Hebrew'],
#  68539: [68539,
#          'Leviticus',
#          '26',
#          '24',
#          'MT',
#          'qal',
#          'perf',
#          'HLKTJ',
#          'Hebrew'],
#  68606: [68606,
#          'Leviticus',
#          '26',
#          '27',
#          'MT',
#          'qal',
#          'perf',
#          'HLKTM',
#          'Hebrew'],
#  68611: [68611,
#          'Leviticus',
#          '26',
#          '28',
#          'MT',
#          'qal',
#          'perf',
#          'HLKTJ',
#          'Hebrew'],
#  68822: [68822, 'Leviticus', '26', '40', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  68828: [68828, 'Leviticus', '26', '41', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  76675: [76675, 'Numbers', '10', '29', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  76690: [76690, 'Numbers', '10', '30', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  76698: [76698, 'Numbers', '10', '30', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  76721: [76721, 'Numbers', '10', '32', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  77738: [77738, 'Numbers', '12', '9', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  78213: [78213, 'Numbers', '13', '26', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  78714: [78714, 'Numbers', '14', '14', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  79179: [79179, 'Numbers', '14', '38', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  80514: [80514, 'Numbers', '16', '25', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  80520: [80520, 'Numbers', '16', '25', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  80962: [80962, 'Numbers', '17', '11', 'MT', 'hif', 'impv', 'HWLK', 'Hebrew'],
#  82898: [82898, 'Numbers', '20', '17', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  83545: [83545, 'Numbers', '21', '22', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  83924: [83924, 'Numbers', '22', '6', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  83957: [83957, 'Numbers', '22', '7', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  84038: [84038, 'Numbers', '22', '11', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  84055: [84055, 'Numbers', '22', '12', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  84076: [84076, 'Numbers', '22', '13', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  84085: [84085, 'Numbers', '22', '13', 'MT', 'qal', 'infc', 'HLK', 'Hebrew'],
#  84099: [84099, 'Numbers', '22', '14', 'MT', 'qal', 'infc', 'HLK', 'Hebrew'],
#  84128: [84128, 'Numbers', '22', '16', 'MT', 'qal', 'infc', 'HLK', 'Hebrew'],
#  84141: [84141, 'Numbers', '22', '17', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  84214: [84214, 'Numbers', '22', '20', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  84237: [84237, 'Numbers', '22', '21', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  84246: [84246, 'Numbers', '22', '22', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  84291: [84291, 'Numbers', '22', '23', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  84556: [84556, 'Numbers', '22', '35', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  84571: [84571, 'Numbers', '22', '35', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  84613: [84613, 'Numbers', '22', '37', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  84644: [84644, 'Numbers', '22', '39', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  84735: [84735, 'Numbers', '23', '3', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  84749: [84749, 'Numbers', '23', '3', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  84814: [84814, 'Numbers', '23', '7', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  84819: [84819, 'Numbers', '23', '7', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  84906: [84906, 'Numbers', '23', '13', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  85142: [85142, 'Numbers', '23', '27', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  85223: [85223, 'Numbers', '24', '1', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  85439: [85439, 'Numbers', '24', '14', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  85442: [85442, 'Numbers', '24', '14', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  85610: [85610, 'Numbers', '24', '25', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  85618: [85618, 'Numbers', '24', '25', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  90612: [90612, 'Numbers', '32', '39', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  90644: [90644, 'Numbers', '32', '41', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  90656: [90656, 'Numbers', '32', '42', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  90803: [90803, 'Numbers', '33', '8', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  93188: [93188, 'Deuteronomy', '1', '19', 'MT', 'qal', 'wayq', 'NLK', 'Hebrew'],
#  93414: [93414, 'Deuteronomy', '1', '30', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  93450: [93450,
#          'Deuteronomy',
#          '1',
#          '31',
#          'MT',
#          'qal',
#          'perf',
#          'HLKTM',
#          'Hebrew'],
#  93470: [93470, 'Deuteronomy', '1', '33', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  93492: [93492,
#          'Deuteronomy',
#          '1',
#          '33',
#          'MT',
#          'qal',
#          'impf',
#          'TLKW',
#          'Hebrew'],
#  93862: [93862, 'Deuteronomy', '2', '7', 'MT', 'qal', 'infc', 'LKTK', 'Hebrew'],
#  94009: [94009,
#          'Deuteronomy',
#          '2',
#          '14',
#          'MT',
#          'qal',
#          'perf',
#          'HLKNW',
#          'Hebrew'],
#  94264: [94264, 'Deuteronomy', '2', '27', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  95227: [95227, 'Deuteronomy', '4', '3', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  96888: [96888, 'Deuteronomy', '5', '30', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  96950: [96950,
#          'Deuteronomy',
#          '5',
#          '33',
#          'MT',
#          'qal',
#          'impf',
#          'TLKW',
#          'Hebrew'],
#  97093: [97093, 'Deuteronomy', '6', '7', 'MT', 'qal', 'infc', 'LKTK', 'Hebrew'],
#  97203: [97203,
#          'Deuteronomy',
#          '6',
#          '14',
#          'MT',
#          'qal',
#          'impf',
#          'TLKWN',
#          'Hebrew'],
#  98031: [98031,
#          'Deuteronomy',
#          '8',
#          '2',
#          'MT',
#          'hif',
#          'perf',
#          'HLJKK',
#          'Hebrew'],
#  98125: [98125, 'Deuteronomy', '8', '6', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  98269: [98269,
#          'Deuteronomy',
#          '8',
#          '15',
#          'MT',
#          'hif',
#          'ptca',
#          'MWLJKK',
#          'Hebrew'],
#  98365: [98365,
#          'Deuteronomy',
#          '8',
#          '19',
#          'MT',
#          'qal',
#          'perf',
#          'HLKT',
#          'Hebrew'],
#  99364: [99364, 'Deuteronomy', '10', '11', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  99402: [99402,
#          'Deuteronomy',
#          '10',
#          '12',
#          'MT',
#          'qal',
#          'infc',
#          'LKT',
#          'Hebrew'],
#  100007: [100007,
#           'Deuteronomy',
#           '11',
#           '19',
#           'MT',
#           'qal',
#           'infc',
#           'LKTK',
#           'Hebrew'],
#  100071: [100071,
#           'Deuteronomy',
#           '11',
#           '22',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  100197: [100197,
#           'Deuteronomy',
#           '11',
#           '28',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  101063: [101063,
#           'Deuteronomy',
#           '13',
#           '3',
#           'MT',
#           'qal',
#           'impf',
#           'NLKH',
#           'Hebrew'],
#  101110: [101110,
#           'Deuteronomy',
#           '13',
#           '5',
#           'MT',
#           'qal',
#           'impf',
#           'TLKW',
#           'Hebrew'],
#  101168: [101168,
#           'Deuteronomy',
#           '13',
#           '6',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  101198: [101198,
#           'Deuteronomy',
#           '13',
#           '7',
#           'MT',
#           'qal',
#           'impf',
#           'NLKH',
#           'Hebrew'],
#  101340: [101340,
#           'Deuteronomy',
#           '13',
#           '14',
#           'MT',
#           'qal',
#           'impf',
#           'NLKH',
#           'Hebrew'],
#  101871: [101871,
#           'Deuteronomy',
#           '14',
#           '25',
#           'MT',
#           'qal',
#           'perf',
#           'HLKT',
#           'Hebrew'],
#  102627: [102627,
#           'Deuteronomy',
#           '16',
#           '7',
#           'MT',
#           'qal',
#           'perf',
#           'HLKT',
#           'Hebrew'],
#  102985: [102985,
#           'Deuteronomy',
#           '17',
#           '3',
#           'MT',
#           'qal',
#           'wayq',
#           'JLK',
#           'Hebrew'],
#  104086: [104086,
#           'Deuteronomy',
#           '19',
#           '9',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  104411: [104411,
#           'Deuteronomy',
#           '20',
#           '4',
#           'MT',
#           'qal',
#           'ptca',
#           'HLK',
#           'Hebrew'],
#  104440: [104440,
#           'Deuteronomy',
#           '20',
#           '5',
#           'MT',
#           'qal',
#           'impf',
#           'JLK',
#           'Hebrew'],
#  104464: [104464,
#           'Deuteronomy',
#           '20',
#           '6',
#           'MT',
#           'qal',
#           'impf',
#           'JLK',
#           'Hebrew'],
#  104488: [104488,
#           'Deuteronomy',
#           '20',
#           '7',
#           'MT',
#           'qal',
#           'impf',
#           'JLK',
#           'Hebrew'],
#  104522: [104522,
#           'Deuteronomy',
#           '20',
#           '8',
#           'MT',
#           'qal',
#           'impf',
#           'JLK',
#           'Hebrew'],
#  106134: [106134,
#           'Deuteronomy',
#           '23',
#           '15',
#           'MT',
#           'hit',
#           'ptca',
#           'MTHLK',
#           'Hebrew'],
#  106376: [106376,
#           'Deuteronomy',
#           '24',
#           '2',
#           'MT',
#           'qal',
#           'perf',
#           'HLKH',
#           'Hebrew'],
#  107201: [107201,
#           'Deuteronomy',
#           '26',
#           '2',
#           'MT',
#           'qal',
#           'perf',
#           'HLKT',
#           'Hebrew'],
#  107592: [107592,
#           'Deuteronomy',
#           '26',
#           '17',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  108253: [108253,
#           'Deuteronomy',
#           '28',
#           '9',
#           'MT',
#           'qal',
#           'perf',
#           'HLKT',
#           'Hebrew'],
#  108380: [108380,
#           'Deuteronomy',
#           '28',
#           '14',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  108787: [108787,
#           'Deuteronomy',
#           '28',
#           '36',
#           'MT',
#           'hif',
#           'impf',
#           'JWLK',
#           'Hebrew'],
#  108878: [108878,
#           'Deuteronomy',
#           '28',
#           '41',
#           'MT',
#           'qal',
#           'impf',
#           'JLKW',
#           'Hebrew'],
#  109604: [109604,
#           'Deuteronomy',
#           '29',
#           '4',
#           'MT',
#           'hif',
#           'wayq',
#           '>WLK',
#           'Hebrew'],
#  109871: [109871,
#           'Deuteronomy',
#           '29',
#           '17',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  109911: [109911,
#           'Deuteronomy',
#           '29',
#           '18',
#           'MT',
#           'qal',
#           'impf',
#           '>LK',
#           'Hebrew'],
#  110090: [110090,
#           'Deuteronomy',
#           '29',
#           '25',
#           'MT',
#           'qal',
#           'wayq',
#           'JLKW',
#           'Hebrew'],
#  110522: [110522,
#           'Deuteronomy',
#           '30',
#           '16',
#           'MT',
#           'qal',
#           'infc',
#           'LKT',
#           'Hebrew'],
#  110664: [110664,
#           'Deuteronomy',
#           '31',
#           '1',
#           'MT',
#           'qal',
#           'wayq',
#           'JLK',
#           'Hebrew'],
#  110784: [110784,
#           'Deuteronomy',
#           '31',
#           '6',
#           'MT',
#           'qal',
#           'ptca',
#           'HLK',
#           'Hebrew'],
#  110833: [110833,
#           'Deuteronomy',
#           '31',
#           '8',
#           'MT',
#           'qal',
#           'ptca',
#           'HLK',
#           'Hebrew'],
#  111010: [111010,
#           'Deuteronomy',
#           '31',
#           '14',
#           'MT',
#           'qal',
#           'wayq',
#           'JLK',
#           'Hebrew'],
#  113089: [113089, 'Joshua', '1', '7', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  113140: [113140, 'Joshua', '1', '9', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  113318: [113318, 'Joshua', '1', '16', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  113372: [113372, 'Joshua', '2', '1', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  113381: [113381, 'Joshua', '2', '1', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  113479: [113479, 'Joshua', '2', '5', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  113734: [113734, 'Joshua', '2', '16', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  113751: [113751, 'Joshua', '2', '16', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  113858: [113858, 'Joshua', '2', '21', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  113869: [113869, 'Joshua', '2', '22', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  114009: [114009, 'Joshua', '3', '3', 'MT', 'qal', 'perf', 'HLKTM', 'Hebrew'],
#  114033: [114033, 'Joshua', '3', '4', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  114084: [114084, 'Joshua', '3', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  114807: [114807, 'Joshua', '4', '18', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  115083: [115083, 'Joshua', '5', '6', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  115291: [115291, 'Joshua', '5', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  115543: [115543, 'Joshua', '6', '8', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  115548: [115548, 'Joshua', '6', '9', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  115559: [115559, 'Joshua', '6', '9', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  115563: [115563, 'Joshua', '6', '9', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  115642: [115642, 'Joshua', '6', '13', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  115643: [115643, 'Joshua', '6', '13', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  115652: [115652, 'Joshua', '6', '13', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  115658: [115658, 'Joshua', '6', '13', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  115662: [115662, 'Joshua', '6', '13', 'MT', 'qal', 'infa', 'HWLK', 'Hebrew'],
#  117003: [117003, 'Joshua', '8', '9', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  117130: [117130, 'Joshua', '8', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  117740: [117740, 'Joshua', '8', '35', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  117821: [117821, 'Joshua', '9', '4', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  117857: [117857, 'Joshua', '9', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  117983: [117983, 'Joshua', '9', '11', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  118007: [118007, 'Joshua', '9', '12', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  118926: [118926, 'Joshua', '10', '24', 'MT', 'qal', 'perf', 'HLKW>', 'Hebrew'],
#  121249: [121249, 'Joshua', '14', '10', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  122298: [122298, 'Joshua', '16', '8', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  122555: [122555, 'Joshua', '17', '7', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  122917: [122917, 'Joshua', '18', '4', 'MT', 'hit', 'impf', 'JTHLKW', 'Hebrew'],
#  123011: [123011, 'Joshua', '18', '8', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  123017: [123017, 'Joshua', '18', '8', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  123025: [123025, 'Joshua', '18', '8', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  123027: [123027, 'Joshua', '18', '8', 'MT', 'hit', 'impv', 'HTHLKW', 'Hebrew'],
#  123048: [123048, 'Joshua', '18', '9', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  125307: [125307, 'Joshua', '22', '4', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  125349: [125349, 'Joshua', '22', '5', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  125377: [125377, 'Joshua', '22', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  125452: [125452, 'Joshua', '22', '9', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  125474: [125474, 'Joshua', '22', '9', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  126516: [126516, 'Joshua', '23', '14', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  126610: [126610, 'Joshua', '23', '16', 'MT', 'qal', 'perf', 'HLKTM', 'Hebrew'],
#  126704: [126704, 'Joshua', '24', '3', 'MT', 'hif', 'wayq', '>WLK', 'Hebrew'],
#  127100: [127100, 'Joshua', '24', '17', 'MT', 'qal', 'perf', 'HLKNW', 'Hebrew'],
#  127507: [127507, 'Judges', '1', '3', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  127514: [127514, 'Judges', '1', '3', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  127641: [127641, 'Judges', '1', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  127667: [127667, 'Judges', '1', '11', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  127786: [127786, 'Judges', '1', '16', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  127793: [127793, 'Judges', '1', '17', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  127969: [127969, 'Judges', '1', '26', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  128325: [128325, 'Judges', '2', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  128452: [128452, 'Judges', '2', '12', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  128565: [128565, 'Judges', '2', '17', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  128617: [128617, 'Judges', '2', '19', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  128691: [128691, 'Judges', '2', '22', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  128984: [128984, 'Judges', '3', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  129504: [129504, 'Judges', '4', '6', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  129549: [129549, 'Judges', '4', '8', 'MT', 'qal', 'impf', 'TLKJ', 'Hebrew'],
#  129552: [129552, 'Judges', '4', '8', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  129556: [129556, 'Judges', '4', '8', 'MT', 'qal', 'impf', 'TLKJ', 'Hebrew'],
#  129559: [129559, 'Judges', '4', '8', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  129562: [129562, 'Judges', '4', '9', 'MT', 'qal', 'infa', 'HLK', 'Hebrew'],
#  129563: [129563, 'Judges', '4', '9', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  129575: [129575, 'Judges', '4', '9', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  129588: [129588, 'Judges', '4', '9', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  129903: [129903, 'Judges', '4', '22', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  129942: [129942, 'Judges', '4', '24', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  129946: [129946, 'Judges', '4', '24', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  130040: [130040, 'Judges', '5', '6', 'MT', 'qal', 'ptca', 'HLKJ', 'Hebrew'],
#  130042: [130042, 'Judges', '5', '6', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  130093: [130093, 'Judges', '5', '10', 'MT', 'qal', 'ptca', 'HLKJ', 'Hebrew'],
#  130719: [130719, 'Judges', '6', '14', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  130910: [130910, 'Judges', '6', '21', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  131513: [131513, 'Judges', '7', '4', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  131516: [131516, 'Judges', '7', '4', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  131525: [131525, 'Judges', '7', '4', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  131529: [131529, 'Judges', '7', '4', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  131615: [131615, 'Judges', '7', '7', 'MT', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  132158: [132158, 'Judges', '8', '1', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  132764: [132764, 'Judges', '8', '29', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  132874: [132874, 'Judges', '9', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  132966: [132966, 'Judges', '9', '4', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  133003: [133003, 'Judges', '9', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  133021: [133021, 'Judges', '9', '7', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  133044: [133044, 'Judges', '9', '8', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  133045: [133045, 'Judges', '9', '8', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  133075: [133075, 'Judges', '9', '9', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  133088: [133088, 'Judges', '9', '10', 'MT', 'qal', 'impv', 'LKJ', 'Hebrew'],
#  133107: [133107, 'Judges', '9', '11', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  133120: [133120, 'Judges', '9', '12', 'MT', 'qal', 'impv', 'LKJ', 'Hebrew'],
#  133139: [133139, 'Judges', '9', '13', 'MT', 'qal', 'perf', 'HLKTJ', 'Hebrew'],
#  133153: [133153, 'Judges', '9', '14', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  133326: [133326, 'Judges', '9', '21', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  133927: [133927, 'Judges', '9', '49', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  133957: [133957, 'Judges', '9', '50', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  134064: [134064, 'Judges', '9', '55', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  134376: [134376, 'Judges', '10', '14', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  134561: [134561, 'Judges', '11', '5', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  134575: [134575, 'Judges', '11', '6', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  134622: [134622, 'Judges', '11', '8', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  134681: [134681, 'Judges', '11', '11', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  134797: [134797, 'Judges', '11', '16', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  134841: [134841, 'Judges', '11', '18', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  135307: [135307, 'Judges', '11', '37', 'MT', 'qal', 'impf', '>LKH', 'Hebrew'],
#  135322: [135322, 'Judges', '11', '38', 'MT', 'qal', 'impv', 'LKJ', 'Hebrew'],
#  135329: [135329, 'Judges', '11', '38', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  135370: [135370, 'Judges', '11', '40', 'MT', 'qal', 'impf', 'TLKNH', 'Hebrew'],
#  135408: [135408, 'Judges', '12', '1', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  135950: [135950, 'Judges', '13', '11', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  136296: [136296, 'Judges', '14', '3', 'MT', 'qal', 'ptca', 'HWLK', 'Hebrew'],
#  136431: [136431, 'Judges', '14', '9', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  136432: [136432, 'Judges', '14', '9', 'MT', 'qal', 'infa', 'HLWK', 'Hebrew'],
#  136436: [136436, 'Judges', '14', '9', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  136808: [136808, 'Judges', '15', '4', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  137205: [137205, 'Judges', '16', '1', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  138162: [138162, 'Judges', '17', '8', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  138203: [138203, 'Judges', '17', '9', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  138238: [138238, 'Judges', '17', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  138361: [138361, 'Judges', '18', '2', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  138440: [138440, 'Judges', '18', '5', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  138447: [138447, 'Judges', '18', '6', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  138454: [138454, 'Judges', '18', '6', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  138457: [138457, 'Judges', '18', '7', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  138535: [138535, 'Judges', '18', '9', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  138631: [138631, 'Judges', '18', '14', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  138702: [138702, 'Judges', '18', '17', 'MT', 'qal', 'ptca', 'HLKJM', 'Hebrew'],
#  138779: [138779, 'Judges', '18', '19', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  138834: [138834, 'Judges', '18', '21', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  138900: [138900, 'Judges', '18', '24', 'MT', 'qal', 'wayq', 'TLKW', 'Hebrew'],
#  138934: [138934, 'Judges', '18', '26', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  139120: [139120, 'Judges', '19', '2', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  139139: [139139, 'Judges', '19', '3', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  139200: [139200, 'Judges', '19', '5', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  139214: [139214, 'Judges', '19', '5', 'MT', 'qal', 'impf', 'TLKW', 'Hebrew'],
#  139243: [139243, 'Judges', '19', '7', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  139264: [139264, 'Judges', '19', '8', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  139287: [139287, 'Judges', '19', '9', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  139324: [139324, 'Judges', '19', '9', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  139337: [139337, 'Judges', '19', '10', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  139367: [139367, 'Judges', '19', '11', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  139403: [139403, 'Judges', '19', '13', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  139422: [139422, 'Judges', '19', '14', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  139513: [139513, 'Judges', '19', '17', 'MT', 'qal', 'impf', 'TLK', 'Hebrew'],
#  139534: [139534, 'Judges', '19', '18', 'MT', 'qal', 'wayq', '>LK', 'Hebrew'],
#  139543: [139543, 'Judges', '19', '18', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  139790: [139790, 'Judges', '19', '27', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  139812: [139812, 'Judges', '19', '28', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  139826: [139826, 'Judges', '19', '28', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  140047: [140047, 'Judges', '20', '8', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  141203: [141203, 'Judges', '21', '10', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  141404: [141404, 'Judges', '21', '20', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  141437: [141437, 'Judges', '21', '21', 'MT', 'qal', 'perf', 'HLKTM', 'Hebrew'],
#  141488: [141488, 'Judges', '21', '23', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  141502: [141502,
#           'Judges',
#           '21',
#           '24',
#           'MT',
#           'hit',
#           'wayq',
#           'JTHLKW',
#           'Hebrew'],
#  141869: [141869, '1_Samuel', '1', '17', 'MT', 'qal', 'impv', 'LKJ', 'Hebrew'],
#  141890: [141890, '1_Samuel', '1', '18', 'MT', 'qal', 'wayq', 'TLK', 'Hebrew'],
#  142266: [142266, '1_Samuel', '2', '11', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  142499: [142499, '1_Samuel', '2', '20', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  142616: [142616, '1_Samuel', '2', '26', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  142720: [142720,
#           '1_Samuel',
#           '2',
#           '30',
#           'MT',
#           'hit',
#           'impf',
#           'JTHLKW',
#           'Hebrew'],
#  142834: [142834,
#           '1_Samuel',
#           '2',
#           '35',
#           'MT',
#           'hit',
#           'perf',
#           'HTHLK',
#           'Hebrew'],
#  142953: [142953, '1_Samuel', '3', '5', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  142966: [142966, '1_Samuel', '3', '6', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  143005: [143005, '1_Samuel', '3', '8', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  143028: [143028, '1_Samuel', '3', '9', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  143043: [143043, '1_Samuel', '3', '9', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  144267: [144267, '1_Samuel', '6', '6', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  144330: [144330, '1_Samuel', '6', '8', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  144418: [144418, '1_Samuel', '6', '12', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  144419: [144419, '1_Samuel', '6', '12', 'MT', 'qal', 'infa', 'HLK', 'Hebrew'],
#  144431: [144431,
#           '1_Samuel',
#           '6',
#           '12',
#           'MT',
#           'qal',
#           'ptca',
#           'HLKJM',
#           'Hebrew'],
#  145047: [145047, '1_Samuel', '7', '16', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  145120: [145120, '1_Samuel', '8', '3', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  145155: [145155, '1_Samuel', '8', '5', 'MT', 'qal', 'perf', 'HLKW', 'Hebrew'],
#  145484: [145484, '1_Samuel', '8', '22', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  145560: [145560, '1_Samuel', '9', '3', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  145605: [145605, '1_Samuel', '9', '5', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  145639: [145639, '1_Samuel', '9', '6', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  145647: [145647, '1_Samuel', '9', '6', 'MT', 'qal', 'perf', 'HLKNW', 'Hebrew'],
#  145656: [145656, '1_Samuel', '9', '7', 'MT', 'qal', 'impf', 'NLK', 'Hebrew'],
#  145717: [145717, '1_Samuel', '9', '9', 'MT', 'qal', 'infc', 'LKTW', 'Hebrew'],
#  145721: [145721, '1_Samuel', '9', '9', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  145723: [145723, '1_Samuel', '9', '9', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  145745: [145745, '1_Samuel', '9', '10', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  145746: [145746, '1_Samuel', '9', '10', 'MT', 'qal', 'impf', 'NLKH', 'Hebrew'],
#  145748: [145748, '1_Samuel', '9', '10', 'MT', 'qal', 'wayq', 'JLKW', 'Hebrew'],
#  146239: [146239, '1_Samuel', '10', '2', 'MT', 'qal', 'infc', 'LKTK', 'Hebrew'],
#  146263: [146263, '1_Samuel', '10', '2', 'MT', 'qal', 'perf', 'HLKT', 'Hebrew'],
#  146438: [146438, '1_Samuel', '10', '9', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  146551: [146551,
#           '1_Samuel',
#           '10',
#           '14',
#           'MT',
#           'qal',
#           'perf',
#           'HLKTM',
#           'Hebrew'],
#  146813: [146813, '1_Samuel', '10', '26', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  146818: [146818,
#           '1_Samuel',
#           '10',
#           '26',
#           'MT',
#           'qal',
#           'wayq',
#           'JLKW',
#           'Hebrew'],
#  147169: [147169, '1_Samuel', '11', '14', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  147171: [147171,
#           '1_Samuel',
#           '11',
#           '14',
#           'MT',
#           'qal',
#           'impf',
#           'NLKH',
#           'Hebrew'],
#  147180: [147180,
#           '1_Samuel',
#           '11',
#           '15',
#           'MT',
#           'qal',
#           'wayq',
#           'JLKW',
#           'Hebrew'],
#  147239: [147239,
#           '1_Samuel',
#           '12',
#           '2',
#           'MT',
#           'hit',
#           'ptca',
#           'MTHLK',
#           'Hebrew'],
#  147253: [147253,
#           '1_Samuel',
#           '12',
#           '2',
#           'MT',
#           'hit',
#           'perf',
#           'HTHLKTJ',
#           'Hebrew'],
#  148326: [148326, '1_Samuel', '14', '1', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  148386: [148386, '1_Samuel', '14', '3', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  148451: [148451, '1_Samuel', '14', '6', 'MT', 'qal', 'impv', 'LKH', 'Hebrew'],
#  148677: [148677, '1_Samuel', '14', '16', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  148693: [148693, '1_Samuel', '14', '17', 'MT', 'qal', 'perf', 'HLK', 'Hebrew'],
#  148743: [148743, '1_Samuel', '14', '19', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  148744: [148744,
#           '1_Samuel',
#           '14',
#           '19',
#           'MT',
#           'qal',
#           'infa',
#           'HLWK',
#           'Hebrew'],
#  149410: [149410,
#           '1_Samuel',
#           '14',
#           '46',
#           'MT',
#           'qal',
#           'perf',
#           'HLKW',
#           'Hebrew'],
#  149579: [149579, '1_Samuel', '15', '3', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  149652: [149652, '1_Samuel', '15', '6', 'MT', 'qal', 'impv', 'LKW', 'Hebrew'],
#  149927: [149927, '1_Samuel', '15', '18', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  149971: [149971, '1_Samuel', '15', '20', 'MT', 'qal', 'wayq', '>LK', 'Hebrew'],
#  150114: [150114, '1_Samuel', '15', '27', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
#  150197: [150197, '1_Samuel', '15', '32', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  150234: [150234, '1_Samuel', '15', '34', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  150292: [150292, '1_Samuel', '16', '1', 'MT', 'qal', 'impv', 'LK', 'Hebrew'],
#  150309: [150309, '1_Samuel', '16', '2', 'MT', 'qal', 'impf', '>LK', 'Hebrew'],
#  150581: [150581, '1_Samuel', '16', '13', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  150911: [150911, '1_Samuel', '17', '7', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  151036: [151036,
#           '1_Samuel',
#           '17',
#           '13',
#           'MT',
#           'qal',
#           'wayq',
#           'JLKW',
#           'Hebrew'],
#  151042: [151042,
#           '1_Samuel',
#           '17',
#           '13',
#           'MT',
#           'qal',
#           'perf',
#           'HLKW',
#           'Hebrew'],
#  151053: [151053,
#           '1_Samuel',
#           '17',
#           '13',
#           'MT',
#           'qal',
#           'perf',
#           'HLKW',
#           'Hebrew'],
#  151076: [151076,
#           '1_Samuel',
#           '17',
#           '14',
#           'MT',
#           'qal',
#           'perf',
#           'HLKW',
#           'Hebrew'],
#  151081: [151081, '1_Samuel', '17', '15', 'MT', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  151184: [151184, '1_Samuel', '17', '20', 'MT', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  151495: [151495, '1_Samuel', '17', '32', 'MT', 'qal', 'impf', 'JLK', 'Hebrew'],
#  151511: [151511, '1_Samuel', '17', '33', 'MT', 'qal', 'infc', 'LKT', 'Hebrew'],
# ...
#  2075742: [2075742,
#            'Genesis',
#            '13',
#            '3',
#            '8Q1',
#            'qal',
#            'wayq',
#            'JLK',
#            'Hebrew'],
#  2075971: [2075971,
#            'Genesis',
#            '18',
#            '22',
#            '8Q1',
#            'qal',
#            'wayq',
#            'JLKW',
#            'Hebrew'],
#  2076711: [2076711,
#            'Deuteronomy',
#            '11',
#            '19',
#            '8Q3',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2076806: [2076806,
#            'Deuteronomy',
#            '6',
#            '7',
#            '8Q3',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2077045: [2077045,
#            'Deuteronomy',
#            '10',
#            '12',
#            '8Q3',
#            'qal',
#            'infc',
#            'LKT',
#            'Hebrew'],
#  2078097: [2078097,
#            'Deuteronomy',
#            '10',
#            '12',
#            '8Q4',
#            'qal',
#            'infc',
#            'LKT',
#            'Hebrew'],
#  2078751: [2078751,
#            'Deuteronomy',
#            '11',
#            '19',
#            '8Q4',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2078954: [2078954,
#            'Leviticus',
#            '11',
#            '27',
#            '11Q1',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2078962: [2078962,
#            'Leviticus',
#            '11',
#            '27',
#            '11Q1',
#            'qal',
#            'ptca',
#            'HLKT',
#            'Hebrew'],
#  2080982: [2080982,
#            'Leviticus',
#            '26',
#            '21',
#            '11Q1',
#            'qal',
#            'impf',
#            'TLKW',
#            'Hebrew'],
#  2081031: [2081031,
#            'Leviticus',
#            '26',
#            '23',
#            '11Q1',
#            'qal',
#            'perf',
#            'HLKTM',
#            'Hebrew'],
#  2081036: [2081036,
#            'Leviticus',
#            '26',
#            '24',
#            '11Q1',
#            'qal',
#            'perf',
#            'HLKTJ',
#            'Hebrew'],
#  2081818: [2081818,
#            'Ezekiel',
#            '1',
#            '9',
#            '11Q4',
#            'qal',
#            'infc',
#            'LKTM',
#            'Hebrew'],
#  2081823: [2081823,
#            'Ezekiel',
#            '1',
#            '9',
#            '11Q4',
#            'qal',
#            'impf',
#            'JLKW',
#            'Hebrew'],
#  2082211: [2082211,
#            'Psalms',
#            '101',
#            '2',
#            '11Q5',
#            'hit',
#            'impf',
#            '>THLK',
#            'Hebrew'],
#  2082263: [2082263,
#            'Psalms',
#            '101',
#            '6',
#            '11Q5',
#            'qal',
#            'ptca',
#            'HLK',
#            'Hebrew'],
#  2082490: [2082490,
#            'Psalms',
#            '109',
#            '23',
#            '11Q5',
#            'nif',
#            'perf',
#            'NHLKTJ',
#            'Hebrew'],
#  2082653: [2082653,
#            'Psalms',
#            '104',
#            '3',
#            '11Q5',
#            'piel',
#            'ptca',
#            'MHLK',
#            'Hebrew'],
#  2082743: [2082743,
#            'Psalms',
#            '104',
#            '26',
#            '11Q5',
#            'piel',
#            'impf',
#            'JHLKWN',
#            'Hebrew'],
#  2083170: [2083170,
#            'Psalms',
#            '105',
#            '41',
#            '11Q5',
#            'qal',
#            'perf',
#            'HLKW',
#            'Hebrew'],
#  2083472: [2083472,
#            'Psalms',
#            '122',
#            '1',
#            '11Q5',
#            'qal',
#            'impf',
#            'NLK',
#            'Hebrew'],
#  2083651: [2083651,
#            'Psalms',
#            '125',
#            '5',
#            '11Q5',
#            'hif',
#            'impf',
#            'JWLJKM',
#            'Hebrew'],
#  2083717: [2083717,
#            'Psalms',
#            '126',
#            '6',
#            '11Q5',
#            'qal',
#            'infa',
#            'HLWK',
#            'Hebrew'],
#  2083718: [2083718,
#            'Psalms',
#            '126',
#            '6',
#            '11Q5',
#            'qal',
#            'impf',
#            'JLK',
#            'Hebrew'],
#  2084060: [2084060,
#            'Psalms',
#            '119',
#            '1',
#            '11Q5',
#            'qal',
#            'ptca',
#            'HWLKJM',
#            'Hebrew'],
#  2084079: [2084079,
#            'Psalms',
#            '119',
#            '3',
#            '11Q5',
#            'qal',
#            'perf',
#            'HLKW',
#            'Hebrew'],
#  2084291: [2084291,
#            'Psalms',
#            '119',
#            '45',
#            '11Q5',
#            'hit',
#            'impf',
#            '>THLKH',
#            'Hebrew'],
#  2085384: [2085384,
#            'Psalms',
#            '136',
#            '16',
#            '11Q5',
#            'hif',
#            'ptca',
#            'MWLJK',
#            'Hebrew'],
#  2086090: [2086090,
#            'Psalms',
#            '138',
#            '7',
#            '11Q5',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew'],
#  2086523: [2086523,
#            'Psalms',
#            '143',
#            '8',
#            '11Q5',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew'],
#  2086716: [2086716,
#            'Psalms',
#            '77',
#            '18',
#            '11Q6',
#            'hit',
#            'impf',
#            'JTHLKW',
#            'Hebrew'],
#  2087185: [2087185,
#            'Psalms',
#            '12',
#            '9',
#            '11Q7',
#            'hit',
#            'impf',
#            'JTHLKWN',
#            'Hebrew'],
#  2087941: [2087941,
#            'Psalms',
#            '39',
#            '14',
#            '11Q8',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew'],
#  2087969: [2087969,
#            'Psalms',
#            '43',
#            '2',
#            '11Q8',
#            'hit',
#            'impf',
#            '>THLK',
#            'Hebrew'],
#  2088259: [2088259,
#            'Psalms',
#            '78',
#            '10',
#            '11Q8',
#            'qal',
#            'infc',
#            'LKT',
#            'Hebrew'],
#  2088872: [2088872,
#            'Deuteronomy',
#            '10',
#            '12',
#            'Xq1',
#            'qal',
#            'infc',
#            'LKT',
#            'Hebrew'],
#  2089238: [2089238,
#            'Deuteronomy',
#            '5',
#            '30',
#            'Xq2',
#            'qal',
#            'impv',
#            'LK',
#            'Hebrew'],
#  2089303: [2089303,
#            'Deuteronomy',
#            '5',
#            '33',
#            'Xq2',
#            'qal',
#            'impf',
#            'TLKW',
#            'Hebrew'],
#  2089455: [2089455,
#            'Deuteronomy',
#            '6',
#            '7',
#            'Xq2',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2090323: [2090323,
#            'Exodus',
#            '4',
#            '29',
#            'Mur1',
#            'qal',
#            'wayq',
#            'JLK',
#            'Hebrew'],
#  2090433: [2090433,
#            'Exodus',
#            '5',
#            '3',
#            'Mur1',
#            'qal',
#            'impf',
#            'NLKH',
#            'Hebrew'],
#  2091465: [2091465,
#            'Deuteronomy',
#            '11',
#            '19',
#            'Mur4',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2091560: [2091560,
#            'Deuteronomy',
#            '6',
#            '7',
#            'Mur4',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2092245: [2092245, 'Amos', '1', '15', 'Mur88', 'qal', 'perf', 'HLK', 'Hebrew'],
#  2092450: [2092450, 'Amos', '7', '12', 'Mur88', 'qal', 'impv', 'LK', 'Hebrew'],
#  2092514: [2092514, 'Amos', '7', '15', 'Mur88', 'qal', 'impv', 'LK', 'Hebrew'],
#  2092865: [2092865, 'Amos', '9', '4', 'Mur88', 'qal', 'impf', 'JLKW', 'Hebrew'],
#  2093572: [2093572, 'Jonah', '1', '2', 'Mur88', 'qal', 'impv', 'LK', 'Hebrew'],
#  2093708: [2093708, 'Jonah', '1', '7', 'Mur88', 'qal', 'impv', 'LKW', 'Hebrew'],
#  2093828: [2093828,
#            'Jonah',
#            '1',
#            '11',
#            'Mur88',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2093877: [2093877,
#            'Jonah',
#            '1',
#            '13',
#            'Mur88',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2094115: [2094115, 'Jonah', '3', '2', 'Mur88', 'qal', 'impv', 'LK', 'Hebrew'],
#  2094137: [2094137, 'Jonah', '3', '3', 'Mur88', 'qal', 'wayq', 'JLK', 'Hebrew'],
#  2094736: [2094736,
#            'Micah',
#            '1',
#            '8',
#            'Mur88',
#            'qal',
#            'impf',
#            '>JLKH',
#            'Hebrew'],
#  2094932: [2094932,
#            'Micah',
#            '2',
#            '3',
#            'Mur88',
#            'qal',
#            'impf',
#            'TLKW',
#            'Hebrew'],
#  2095006: [2095006, 'Micah', '2', '7', 'Mur88', 'qal', 'ptca', 'HLK', 'Hebrew'],
#  2095041: [2095041,
#            'Micah',
#            '2',
#            '10',
#            'Mur88',
#            'qal',
#            'impv',
#            'LKW',
#            'Hebrew'],
#  2095057: [2095057,
#            'Micah',
#            '2',
#            '11',
#            'Mur88',
#            'qal',
#            'ptca',
#            'HLK',
#            'Hebrew'],
#  2095399: [2095399,
#            'Micah',
#            '4',
#            '2',
#            'Mur88',
#            'qal',
#            'perf',
#            'HLKW',
#            'Hebrew'],
#  2095404: [2095404, 'Micah', '4', '2', 'Mur88', 'qal', 'impv', 'LKW', 'Hebrew'],
#  2095420: [2095420,
#            'Micah',
#            '4',
#            '2',
#            'Mur88',
#            'qal',
#            'impf',
#            'NLKH',
#            'Hebrew'],
#  2095488: [2095488,
#            'Micah',
#            '4',
#            '5',
#            'Mur88',
#            'qal',
#            'impf',
#            'JLKW',
#            'Hebrew'],
#  2095495: [2095495, 'Micah', '4', '5', 'Mur88', 'qal', 'impf', 'NLK', 'Hebrew'],
#  2096102: [2096102,
#            'Micah',
#            '6',
#            '16',
#            'Mur88',
#            'qal',
#            'wayq',
#            'TLKW',
#            'Hebrew'],
#  2096865: [2096865,
#            'Nahum',
#            '2',
#            '12',
#            'Mur88',
#            'qal',
#            'perf',
#            'HLK',
#            'Hebrew'],
#  2097067: [2097067,
#            'Nahum',
#            '3',
#            '10',
#            'Mur88',
#            'qal',
#            'perf',
#            'HLKH',
#            'Hebrew'],
#  2097307: [2097307,
#            'Habakkuk',
#            '1',
#            '6',
#            'Mur88',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2097777: [2097777,
#            'Habakkuk',
#            '3',
#            '5',
#            'Mur88',
#            'qal',
#            'impf',
#            'JLK',
#            'Hebrew'],
#  2097865: [2097865,
#            'Habakkuk',
#            '3',
#            '11',
#            'Mur88',
#            'piel',
#            'impf',
#            'JHLKW',
#            'Hebrew'],
#  2098156: [2098156,
#            'Zephaniah',
#            '1',
#            '17',
#            'Mur88',
#            'qal',
#            'perf',
#            'HLKW',
#            'Hebrew'],
#  2100067: [2100067,
#            'Genesis',
#            '36',
#            '6',
#            'Sdeir1',
#            'qal',
#            'wayq',
#            'JLK',
#            'Hebrew'],
#  2100799: [2100799,
#            'Psalms',
#            '12',
#            '9',
#            '5/6hev1b',
#            'hit',
#            'impf',
#            'JTHLKWN',
#            'Hebrew'],
#  2100889: [2100889,
#            'Psalms',
#            '15',
#            '2',
#            '5/6hev1b',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2101483: [2101483,
#            'Psalms',
#            '23',
#            '4',
#            '5/6hev1b',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew'],
#  2102705: [2102705,
#            'Deuteronomy',
#            '6',
#            '7',
#            'Xhev/se5',
#            'qal',
#            'infc',
#            'LKT',
#            'Hebrew'],
#  2102880: [2102880,
#            'Deuteronomy',
#            '11',
#            '19',
#            'Xhev/se5',
#            'qal',
#            'infc',
#            'LKTK',
#            'Hebrew'],
#  2104652: [2104652,
#            'Leviticus',
#            '11',
#            '20',
#            'Mas1b',
#            'qal',
#            'ptca',
#            'HLK',
#            'Hebrew'],
#  2104669: [2104669,
#            'Leviticus',
#            '11',
#            '21',
#            'Mas1b',
#            'qal',
#            'ptca',
#            'HLK',
#            'Hebrew'],
#  2104734: [2104734,
#            'Leviticus',
#            '11',
#            '27',
#            'Mas1b',
#            'qal',
#            'ptca',
#            'HWLK',
#            'Hebrew'],
#  2104742: [2104742,
#            'Leviticus',
#            '11',
#            '27',
#            'Mas1b',
#            'qal',
#            'ptca',
#            'HLKT',
#            'Hebrew'],
#  2105605: [2105605,
#            'Ezekiel',
#            '36',
#            '12',
#            'Mas1d',
#            'hif',
#            'perf',
#            'HWLKTJ',
#            'Hebrew'],
#  2105914: [2105914,
#            'Ezekiel',
#            '36',
#            '27',
#            'Mas1d',
#            'qal',
#            'impf',
#            'TLKW',
#            'Hebrew'],
#  2106766: [2106766,
#            'Psalms',
#            '81',
#            '13',
#            'Mas1e',
#            'qal',
#            'impf',
#            'JLKW',
#            'Hebrew'],
#  2106777: [2106777,
#            'Psalms',
#            '81',
#            '14',
#            'Mas1e',
#            'piel',
#            'impf',
#            'JHLKW',
#            'Hebrew'],
#  2106858: [2106858,
#            'Psalms',
#            '82',
#            '5',
#            'Mas1e',
#            'hit',
#            'impf',
#            'JTHLKW',
#            'Hebrew'],
#  2106932: [2106932,
#            'Psalms',
#            '83',
#            '5',
#            'Mas1e',
#            'qal',
#            'impv',
#            'LKW',
#            'Hebrew'],
#  2107165: [2107165,
#            'Psalms',
#            '84',
#            '8',
#            'Mas1e',
#            'qal',
#            'impf',
#            'JLKW',
#            'Hebrew'],
#  2107227: [2107227,
#            'Psalms',
#            '84',
#            '12',
#            'Mas1e',
#            'qal',
#            'ptca',
#            'HLKJM',
#            'Hebrew'],
#  2107525: [2107525,
#            'Joshua',
#            '1',
#            '9',
#            'Xjoshua',
#            'qal',
#            'impf',
#            'TLK',
#            'Hebrew'],
#  2107629: [2107629,
#            'Judges',
#            '1',
#            '10',
#            'Xjudges',
#            'qal',
#            'wayq',
#            'JLK',
#            'Hebrew'],
#  2107657: [2107657,
#            'Judges',
#            '1',
#            '11',
#            'Xjudges',
#            'qal',
#            'wayq',
#            'JLK',
#            'Hebrew'],
#  2107769: [2107769,
#            'Judges',
#            '4',
#            '6',
#            'Xjudges',
#            'qal',
#            'impv',
#            'LK',
#            'Hebrew'],
#  2107816: [2107816,
#            'Judges',
#            '4',
#            '8',
#            'Xjudges',
#            'qal',
#            'impf',
#            'TLKJ',
#            'Hebrew'],
#  2107819: [2107819,
#            'Judges',
#            '4',
#            '8',
#            'Xjudges',
#            'qal',
#            'perf',
#            'HLKTJ',
#            'Hebrew'],
#  2107823: [2107823,
#            'Judges',
#            '4',
#            '8',
#            'Xjudges',
#            'qal',
#            'impf',
#            'TLKJ',
#            'Hebrew'],
#  2107826: [2107826,
#            'Judges',
#            '4',
#            '8',
#            'Xjudges',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew'],
#  2107830: [2107830,
#            'Judges',
#            '4',
#            '9',
#            'Xjudges',
#            'qal',
#            'infa',
#            'HLK',
#            'Hebrew'],
#  2107831: [2107831,
#            'Judges',
#            '4',
#            '9',
#            'Xjudges',
#            'qal',
#            'impf',
#            '>LK',
#            'Hebrew']}

# %%
len(halak_info)
# Out:
# 2280

# %%
halak_dataframe = pd.DataFrame(halak_info).T

# %%
halak_dataframe.columns = ["word", "book", "chapter", "verse", "scroll_name", "stem", "verbal_tense", "consonant_rep", "language"]

# %%
halak_dataframe.head()
# Out:
#       word     book chapter verse scroll_name stem verbal_tense consonant_rep  \
# 935    935  Genesis       2    14          MT  qal         ptca           HLK
# 1321  1321  Genesis       3     8          MT  hit         ptca         MTHLK
# 1449  1449  Genesis       3    14          MT  qal         impf           TLK
# 2424  2424  Genesis       5    22          MT  hit         wayq         JTHLK
# 2455  2455  Genesis       5    24          MT  hit         wayq         JTHLK
#
#      language
# 935    Hebrew
# 1321   Hebrew
# 1449   Hebrew
# 2424   Hebrew
# 2455   Hebrew

# %%
halak_dataframe.stem.value_counts()
# Out:
# qal     2067
# hit       93
# hif       72
# piel      38
# peal       4
# nif        2
# haf        2
# pael       2
# Name: stem, dtype: int64

# %%
halak_dataframe.language.value_counts()
# Out:
# Hebrew     2272
# Aramaic       8
# Name: language, dtype: int64

# %%
pd.crosstab(halak_dataframe.stem, halak_dataframe.language)
# Out:
# language  Aramaic  Hebrew
# stem
# haf             2       0
# hif             0      72
# hit             0      93
# nif             0       2
# pael            2       0
# peal            4       0
# piel            0      38
# qal             0    2067

# %%
halak_dataframe.to_csv("halak_data.csv", sep="\t", index=False)

# %%
pd.read_csv("halak_data.csv", sep="\t")
# Out:
#          word     book  chapter  verse scroll_name stem verbal_tense  \
# 0         935  Genesis        2     14          MT  qal         ptca
# 1        1321  Genesis        3      8          MT  hit         ptca
# 2        1449  Genesis        3     14          MT  qal         impf
# 3        2424  Genesis        5     22          MT  hit         wayq
# 4        2455  Genesis        5     24          MT  hit         wayq
# ...       ...      ...      ...    ...         ...  ...          ...
# 2275  2107819   Judges        4      8     Xjudges  qal         perf
# 2276  2107823   Judges        4      8     Xjudges  qal         impf
# 2277  2107826   Judges        4      8     Xjudges  qal         impf
# 2278  2107830   Judges        4      9     Xjudges  qal         infa
# 2279  2107831   Judges        4      9     Xjudges  qal         impf
#
#      consonant_rep language
# 0              HLK   Hebrew
# 1            MTHLK   Hebrew
# 2              TLK   Hebrew
# 3            JTHLK   Hebrew
# 4            JTHLK   Hebrew
# ...            ...      ...
# 2275         HLKTJ   Hebrew
# 2276          TLKJ   Hebrew
# 2277           >LK   Hebrew
# 2278           HLK   Hebrew
# 2279           >LK   Hebrew
#
# [2280 rows x 9 columns]
